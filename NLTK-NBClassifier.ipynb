# %%
import os
import joblib
import pandas as pd
from string import punctuation
from nltk.corpus import wordnet, stopwords
from nltk.tokenize import word_tokenize
from nltk.classify import NaiveBayesClassifier, accuracy
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Symptom2Disease.csv')
df.head()
# Out:
#    Unnamed: 0      label                                               text
# 0           0  Psoriasis  I have been experiencing a skin rash on my arm...
# 1           1  Psoriasis  My skin has been peeling, especially on my kne...
# 2           2  Psoriasis  I have been experiencing joint pain in my fing...
# 3           3  Psoriasis  There is a silver like dusting on my skin, esp...
# 4           4  Psoriasis  My nails have small dents or pits in them, and...

# %%
df['label'].value_counts()
# Out:
# label
# Psoriasis                          50
# Varicose Veins                     50
# Typhoid                            50
# Chicken pox                        50
# Impetigo                           50
# Dengue                             50
# Fungal infection                   50
# Common Cold                        50
# Pneumonia                          50
# Dimorphic Hemorrhoids              50
# Arthritis                          50
# Acne                               50
# Bronchial Asthma                   50
# Hypertension                       50
# Migraine                           50
# Cervical spondylosis               50
# Jaundice                           50
# Malaria                            50
# urinary tract infection            50
# allergy                            50
# gastroesophageal reflux disease    50
# drug reaction                      50
# peptic ulcer disease               50
# diabetes                           50
# Name: count, dtype: int64

# %%
def tag_to_wordnet(tag: str):
    if tag.startswith('J'):
        return wordnet.ADJ
    if tag.startswith('V'):
        return wordnet.VERB
    if tag.startswith('R'):
        return wordnet.ADV
    if tag.startswith('N'):
        return wordnet.NOUN
    return wordnet.NOUN

def preprocess(sentences: str):
    tokens = word_tokenize(sentences)
    cleaned_tokens = [token.lower() for token in tokens if token.lower() not in stopwords.words('english') and token.lower() not in punctuation]
    tagged_tokens = pos_tag(cleaned_tokens)
    stemmed_tokens = [WordNetLemmatizer().lemmatize(token, tag_to_wordnet(tag)) for token, tag in tagged_tokens]
    return stemmed_tokens

def feature_extraction(tokens: list[str], fd: FreqDist):
    dict_feature = {}
    for token in fd.keys():
        dict_feature[token] = (token in tokens)
    return dict_feature

# %%
sentences = "  ".join(df['text'])
print(sentences)

cleaned_tokens = preprocess(sentences)
print(cleaned_tokens)
fd = FreqDist(cleaned_tokens)

X = df['text']
y = df['label']
# Out:
# I have been experiencing a skin rash on my arms, legs, and torso for the past few weeks. It is red, itchy, and covered in dry, scaly patches.  My skin has been peeling, especially on my knees, elbows, and scalp. This peeling is often accompanied by a burning or stinging sensation.  I have been experiencing joint pain in my fingers, wrists, and knees. The pain is often achy and throbbing, and it gets worse when I move my joints.  There is a silver like dusting on my skin, especially on my lower back and scalp. This dusting is made up of small scales that flake off easily when I scratch them.  My nails have small dents or pits in them, and they often feel inflammatory and tender to the touch. Even there are minor rashes on my arms.  The skin on my palms and soles is thickened and has deep cracks. These cracks are painful and bleed easily.  The skin around my mouth, nose, and eyes is red and inflamed. It is often itchy and uncomfortable. There is a noticeable inflammation in my nails.  My skin is very sensitive and reacts easily to changes in temperature or humidity. I often have to be careful about what products I use on my skin.  I have noticed a sudden peeling of skin at different parts of my body, mainly arms, legs and back. Also, I face severe joint pain and skin rashes.  The skin on my genitals is red and inflamed. It is often itchy, burning, and uncomfortable. There are rashes on different parts of the body too.  I have experienced fatigue and a general feeling of malaise. I often feel tired and have a lack of energy, even after a good night's sleep.  The rash on my skin has spread to other parts of my body, including my chest and abdomen. It is itchy and uncomfortable, and it is often worse at night. I am also facing skin peeling.  The rash on my skin is worse in the winter months when the air is dry. I find that I have to moisturize more frequently and use humidifiers to keep my skin hydrated.  I have experienced difficulty sleeping due to the itching and discomfort caused by the rash. There are small dents in my nails, which is really concerning.  My skin is prone to infections due to dry, flaky patches. I am experiencing a strong pain in my joints. The skin on my knees and elbows is starting to peel off.  I am starting to have rashes on my skin. The rash often bleeds when I scratch or rub it. Moreover, I have noticed small dents in my nails.  I have noticed that my skin has become more sensitive than it used to be. There is a silver like dusting on my skin, especially on my back and elbows.  I am worried about the constant peeling of the skin on my palm, elbow and knee. I have developed rashes on my arms, which itch if I touch them. All of these are making my life quite discomforting and miserable.  There is strange pain in my joints. Also, I have noticed strange peeling of skin in different parts of my body. I am afraid there is something wrong going on with my body.  My nails have small dents on them. Even my joints have started to pain severely. There is a silver like dusting on my skin, particularly in my back.  The rashes on my skin are not healing. Moreover, I have noticed a sudden peeling of the skin, especially the skin on my elbows and knees. I am really worried about this.  For the past few weeks, I've had a skin rash on my arms, legs, and chest. It's red and irritating, with dry, scaly spots. I have a strange pain in my joints too.  My skin is peeling, particularly on my knees, elbows, and scalp. This peeling is frequently accompanied by a stinging or burning feeling.  I'm having joint discomfort in my fingers, wrists, and knees. The pain is frequently aching and throbbing, and it worsens when I move my joints.  My skin has a silvery film, particularly on my back, arms and scalp. This dusting is composed of tiny scales that easily peel off when scratched.  I have red and inflammatory skin around my mouth, nose, and eyes. It is frequently irritating and unpleasant. Recently, it has got very painful.  My skin  ...
# ['experience', 'skin', 'rash', 'arm', 'legs', 'torso', 'past', 'week', 'red', 'itchy', 'cover', 'dry', 'scaly', 'patch', 'skin', 'peel', 'especially', 'knee', 'elbow', 'scalp', 'peel', 'often', 'accompany', 'burn', 'sting', 'sensation', 'experience', 'joint', 'pain', 'finger', 'wrists', 'knee', 'pain', 'often', 'achy', 'throb', 'get', 'bad', 'move', 'joint', 'silver', 'like', 'dust', 'skin', 'especially', 'low', 'back', 'scalp', 'dusting', 'make', 'small', 'scale', 'flake', 'easily', 'scratch', 'nail', 'small', 'dent', 'pit', 'often', 'feel', 'inflammatory', 'tender', 'touch', 'even', 'minor', 'rash', 'arm', 'skin', 'palm', 'sol', 'thicken', 'deep', 'crack', 'crack', 'painful', 'bleed', 'easily', 'skin', 'around', 'mouth', 'nose', 'eye', 'red', 'inflamed', 'often', 'itchy', 'uncomfortable', 'noticeable', 'inflammation', 'nail', 'skin', 'sensitive', 'reacts', 'easily', 'change', 'temperature', 'humidity', 'often', 'careful', 'product', 'use', 'skin', 'notice', 'sudden', 'peeling', 'skin', 'different', 'part', 'body', 'mainly', 'arm', 'leg', 'back', 'also', 'face', 'severe', 'joint', 'pain', 'skin', 'rash', 'skin', 'genitals', 'red', 'inflamed', 'often', 'itchy', 'burn', 'uncomfortable', 'rash', 'different', 'part', 'body', 'experience', 'fatigue', 'general', 'feeling', 'malaise', 'often', 'feel', 'tired', 'lack', 'energy', 'even', 'good', 'night', "'s", 'sleep', 'rash', 'skin', 'spread', 'part', 'body', 'include', 'chest', 'abdomen', 'itchy', 'uncomfortable', 'often', 'bad', 'night', 'also', 'face', 'skin', 'peel', 'rash', 'skin', 'bad', 'winter', 'month', 'air', 'dry', 'find', 'moisturize', 'frequently', 'use', 'humidifiers', 'keep', 'skin', 'hydrate', 'experience', 'difficulty', 'sleep', 'due', 'itch', 'discomfort', 'cause', 'rash', 'small', 'dent', 'nail', 'really', 'concern', 'skin', 'prone', 'infection', 'due', 'dry', 'flaky', 'patch', 'experience', 'strong', 'pain', 'joint', 'skin', 'knee', 'elbow', 'start', 'peel', 'start', 'rash', 'skin', 'rash', 'often', 'bleed', 'scratch', 'rub', 'moreover', 'notice', 'small', 'dent', 'nail', 'notice', 'skin', 'become', 'sensitive', 'use', 'silver', 'like', 'dust', 'skin', 'especially', 'back', 'elbow', 'worry', 'constant', 'peeling', 'skin', 'palm', 'elbow', 'knee', 'develop', 'rash', 'arm', 'itch', 'touch', 'make', 'life', 'quite', 'discomforting', 'miserable', 'strange', 'pain', 'joint', 'also', 'notice', 'strange', 'peel', 'skin', 'different', 'part', 'body', 'afraid', 'something', 'wrong', 'go', 'body', 'nail', 'small', 'dent', 'even', 'joint', 'start', 'pain', 'severely', 'silver', 'like', 'dust', 'skin', 'particularly', 'back', 'rashes', 'skin', 'heal', 'moreover', 'notice', 'sudden', 'peeling', 'skin', 'especially', 'skin', 'elbow', 'knee', 'really', 'worry', 'past', 'week', "'ve", 'skin', 'rash', 'arm', 'legs', 'chest', "'s", 'red', 'irritating', 'dry', 'scaly', 'spot', 'strange', 'pain', 'joint', 'skin', 'peel', 'particularly', 'knee', 'elbow', 'scalp', 'peel', 'frequently', 'accompany', 'sting', 'burn', 'feel', "'m", 'joint', 'discomfort', 'finger', 'wrists', 'knee', 'pain', 'frequently', 'ache', 'throb', 'worsens', 'move', 'joint', 'skin', 'silvery', 'film', 'particularly', 'back', 'arm', 'scalp', 'dust', 'compose', 'tiny', 'scale', 'easily', 'peel', 'scratch', 'red', 'inflammatory', 'skin', 'around', 'mouth', 'nose', 'eye', 'frequently', 'irritate', 'unpleasant', 'recently', 'get', 'painful', 'skin', 'extremely', 'sensitive', 'quickly', 'irritate', 'change', 'temperature', 'humidity', 'nail', 'develop', 'dent', 'worried', 'sudden', 'change', "'ve", 'see', 'sudden', 'peel', 'skin', 'various', 'region', 'body', 'mostly', 'arm', 'legs', 'back', 'addition', 'significant', 'joint', 'pain', 'skin', 'rash', 'rash', 'spread', 'different', 'part', 'body', 'genital', 'skin', 'red', 'irritated', 'frequently', 'irritate', 'burn', 'unpleasant', 'also', 'rashes', 'various', 'place', 'body', 'also', 'strange', 'pain', 'joint', "'ve", 'trouble', 'sleep', 'itch', 'pain', 'produce', 'rash' ...

# %%
def train_model():
    all_statement = [
        (feature_extraction(preprocess(statement), fd), sentiment)
        for statement, sentiment in zip(X, y)
    ]
    train_data, test_data = train_test_split(
        all_statement, test_size=0.2, random_state=42
    )
    classifier = NaiveBayesClassifier.train(train_data)
    print(classifier.show_most_informative_features(5))
    print(accuracy(classifier, test_data))
    return classifier, test_data

# %%
model, test_data = train_model()

os.makedirs("models", exist_ok=True)
joblib.dump(model, "models/nltk_nb_model.joblib", compress=True)

y_true = [label for _, label in test_data]
y_pred = [model.classify(features) for features, _ in test_data]

print("\nClassification Report\n")
print(classification_report(y_true, y_pred))

weighted_precision, weighted_recall, weighted_f1, _ = precision_recall_fscore_support(
    y_true,
    y_pred,
    average="weighted",
    zero_division=0
 )

metrics_df = pd.DataFrame([
    {"metric": "accuracy", "value": accuracy(model, test_data)},
    {"metric": "weighted_precision", "value": weighted_precision},
    {"metric": "weighted_recall", "value": weighted_recall},
    {"metric": "weighted_f1", "value": weighted_f1}
])

print(metrics_df)
# Out:
# Most Informative Features
#                     neck = True           Cervic : Psoria =     29.7 : 1.0
#                     back = False            Acne : Cervic =     29.0 : 1.0
#                     rash = False          Cervic : Acne   =     29.0 : 1.0
#                     skin = False          Cervic : Acne   =     29.0 : 1.0
#                     high = False          drug r : Malari =     26.4 : 1.0
# None
# 0.9666666666666667
#
# Classification Report
#
#                                  precision    recall  f1-score   support
#
#                            Acne       1.00      1.00      1.00         7
#                       Arthritis       1.00      1.00      1.00        10
#                Bronchial Asthma       1.00      1.00      1.00        11
#            Cervical spondylosis       1.00      1.00      1.00         7
#                     Chicken pox       0.92      0.92      0.92        12
#                     Common Cold       1.00      0.92      0.96        12
#                          Dengue       0.91      0.83      0.87        12
#           Dimorphic Hemorrhoids       1.00      1.00      1.00         7
#                Fungal infection       1.00      1.00      1.00        13
#                    Hypertension       1.00      1.00      1.00        10
#                        Impetigo       1.00      1.00      1.00        11
#                        Jaundice       1.00      1.00      1.00        11
#                         Malaria       1.00      1.00      1.00        11
#                        Migraine       1.00      1.00      1.00        10
#                       Pneumonia       1.00      1.00      1.00        11
#                       Psoriasis       1.00      0.83      0.91         6
#                         Typhoid       0.75      1.00      0.86         9
#                  Varicose Veins       1.00      1.00      1.00        12
#                         allergy       0.92      1.00      0.96        12
#                        diabetes       1.00      1.00      1.00         8
#                   drug reaction       1.00      1.00      1.00         5
# gastroesophageal reflux disease       0.85      1.00      0.92        11
#            peptic ulcer disease       1.00      0.73      0.84        11
#         urinary tract infection       1.00      1.00      1.00        11
#
#                        accuracy                           0.97       240
#                       macro avg       0.97      0.97      0.97       240
#                    weighted avg       0.97      0.97      0.97       240
#
#                metric     value
# 0            accuracy  0.966667
# 1  weighted_precision  0.971015
# 2     weighted_recall  0.966667
# 3         weighted_f1  0.966452

# %%
cm = confusion_matrix(y_true, y_pred, labels=sorted(set(y_true)))

plt.figure(figsize=(12, 10))
sns.heatmap(
    cm,
    annot=True,
    cmap="Blues",
    xticklabels=sorted(set(y_true)),
    yticklabels=sorted(set(y_true))
 )
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()
